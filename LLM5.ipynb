# %%
# !pip install langchain
# !pip install streamlit
# !pip install PyPDF2
# Out:
# Requirement already satisfied: langchain in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (0.2.17)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langchain) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langchain) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langchain) (3.10.11)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.43 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langchain) (0.2.43)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langchain) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langchain) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langchain) (1.24.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langchain) (2.32.4)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.15.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langchain-core<0.3.0,>=0.2.43->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langchain-core<0.3.0,>=0.2.43->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langchain-core<0.3.0,>=0.2.43->langchain) (4.13.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from pydantic<3,>=1->langchain) (2.23.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from requests<3,>=2->langchain) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from requests<3,>=2->langchain) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from requests<3,>=2->langchain) (2025.10.5)
# Requirement already satisfied: greenlet>=1 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.5.2)
# Requirement already satisfied: httpcore==1.* in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.43->langchain) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: streamlit in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (1.40.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (5.4.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (1.24.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (2.32.4)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (4.13.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from streamlit) (4.0.2)
# Requirement already satisfied: jinja2 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.5.2 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from altair<6,>=4.0->streamlit) (1.42.1)
# Requirement already satisfied: colorama in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.10.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.19.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (6.4.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from importlib-resources>=1.4.0->jsonschema>=3.0->altair<6,>=4.0->streamlit) (3.20.2)
# Requirement already satisfied: PyPDF2 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (3.0.1)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in c:\users\chogu\anaconda3\envs\11m\lib\site-packages (from PyPDF2) (4.13.2)

# %%
import streamlit as st
from PyPDF2 import PdfReader
from langchain.embeddings import OpenAIEmbeddings, SentenceTransformerEmbeddings
from langchain.chat_models import ChatOpenAI
from langchain.chains import ConversationalRetrievalChain, RetrievalQA
from langchain.memory import ConversationBufferWindowMemory
from langchain.vectorstores import FAISS
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
# PDF 문서에서 텍스트 추출
def get_pdf_text(pdf_docs):
    text = ""
    for pdf in pdf_docs:
        pdf_reader = PdfReader(pdf)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text


# 지정된 크기에 따라 주어진 텍스트를 더 작은 덩어리로 분할
def get_text_chunks(text):
    text_splitter = RecursiveCharacterTextSplitter(
        separator="\n",
        chunk_size=1000,
        chunk_overlap=200,
        length_function=len
    )
    chunks = text_splitter.split_text(text)
    return chunks


# 추출된 텍스트 조각에 대한 임베딩을 생성하며 벡터DB(FAISS)를 사용하여 벡터 저장소를 만듬
def get_vectorstore(text_chunks):
    embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
    vectorstore = FAISS.from_texts(text_chunks, embedding=embeddings)
    return vectorstore

# %%
import os
os.environ["OPENAI_API_KEY"] = "sk"   # openai 키 입력

def get_conversation_chain(vectorstore):

    # ConversationBufferWindowMemory() 이전 대화 저장
    memory = ConversationBufferWindowMemory(
        memory_key='chat_history',
        return_messages=True
    )

    # ConversationalRetrievalChain을 통해 챗봇의 질문에 대해 적절히 처리 적용
    conversation_chain = ConversationalRetrievalChain.from_llm(
        llm=ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo-16k-0613"),
        retriever=vectorstore.as_retriever(),
        get_chat_history=lambda h: h,
        memory=memory
    )

    return conversation_chain

# %%
user_uploads = st.file_uploader("파일을 업로드해주세요~", accept_multiple_files=True)

if user_uploads is not None:
    if st.button("Upload"):
        with st.spinner("문서 로딩중..."):
            
            # pdf 텍스트 가져오기
            raw_text = get_pdf_text(user_uploads)

            # 텍스트를 작은 청크로 분할
            text_chunks = get_text_chunks(raw_text)

            # 텍스트 조각에 대한 임베딩 생성 & 벡터 저장소 생성하기
            vectorstore = get_vectorstore(text_chunks)

            # 대화 체인 만들기
            st.session_state.conversation = get_conversation_chain(vectorstore)
# Out:
# 2025-11-13 12:55:57.574 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-13 12:55:57.575 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-13 12:55:57.576 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-13 12:55:57.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-13 12:55:58.197
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\chogu\anaconda3\envs\11m\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-13 12:55:58.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-13 12:55:58.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-13 12:55:58.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-13 12:55:58.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-13 12:55:58.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-13 12:55:58.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
